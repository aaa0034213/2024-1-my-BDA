# %% [markdown]
# <a href="https://colab.research.google.com/github/aaa0034213/2024-1-my-BDA/blob/main/inclass/02w_0319_tue_dataframe_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **빅데이터분석프로그래밍**

# %% [markdown]
# # 파이썬 설치 확인

# %%
import sys
import pandas as pd
import numpy as np

print(sys.version)
print(pd.__version__)
print(np.__version__)
# Out:
# 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# 1.5.3
# 1.25.2

# %% [markdown]
# ## 코랩에서 한글 처리

# %%
# !pip install koreanize_matplotlib

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib

plt.plot([-10,5,-3,1])
plt.title('그래프 제목')
plt.xlabel('직선')
plt.show()

# %% [markdown]
# ## 데이터분석을 위한 seaborn 내장(토이) 데이터, titanic

# %%
import seaborn as sns
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
sns.countplot(titanic, x="sex")
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(titanic, x="class")
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.countplot(titanic, x="deck",hue='deck');

# %%
sns.countplot(titanic, x='class',hue='alive'); ## hue 나눠서

# %%
sns.countplot(titanic, x="who",hue='alive',stat='percent');

# %% [markdown]
# ## 열 검사

# %%
titanic['pclass']  ## 결과가 series
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %%
type(titanic['pclass'])
# Out:
# pandas.core.series.Series

# %%
titanic.pclass
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %%
titanic[['pclass']] ## 결과가 dataframe [[]]
# Out:
#      pclass
# 0         3
# 1         1
# 2         3
# 3         1
# 4         3
# ..      ...
# 886       2
# 887       1
# 888       3
# 889       1
# 890       3
#
# [891 rows x 1 columns]

# %%
titanic[['pclass','alive']]
# Out:
#      pclass alive
# 0         3    no
# 1         1   yes
# 2         3   yes
# 3         1   yes
# 4         3    no
# ..      ...   ...
# 886       2    no
# 887       1   yes
# 888       3    no
# 889       1   yes
# 890       3    no
#
# [891 rows x 2 columns]

# %%
titanic.pclass.values
# Out:
# array([3, 1, 3, 1, 3, 3, 1, 3, 3, 2, 3, 1, 3, 3, 3, 2, 3, 2, 3, 3, 2, 2,
#        3, 1, 3, 3, 3, 1, 3, 3, 1, 1, 3, 2, 1, 1, 3, 3, 3, 3, 3, 2, 3, 2,
#        3, 3, 3, 3, 3, 3, 3, 3, 1, 2, 1, 1, 2, 3, 2, 3, 3, 1, 1, 3, 1, 3,
#        2, 3, 3, 3, 2, 3, 2, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 1, 2, 3, 3, 3,
#        1, 3, 3, 3, 1, 3, 3, 3, 1, 1, 2, 2, 3, 3, 1, 3, 3, 3, 3, 3, 3, 3,
#        1, 3, 3, 3, 3, 3, 3, 2, 1, 3, 2, 3, 2, 2, 1, 3, 3, 3, 3, 3, 3, 3,
#        3, 2, 2, 2, 1, 1, 3, 1, 3, 3, 3, 3, 2, 2, 3, 3, 2, 2, 2, 1, 3, 3,
#        3, 1, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 1, 3, 1, 3, 1, 3, 3, 3, 1, 3,
#        3, 1, 2, 3, 3, 2, 3, 2, 3, 1, 3, 1, 3, 3, 2, 2, 3, 2, 1, 1, 3, 3,
#        3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 1, 3, 2, 3, 2, 3, 1, 3, 2, 1, 2,
#        3, 2, 3, 3, 1, 3, 2, 3, 2, 3, 1, 3, 2, 3, 2, 3, 2, 2, 2, 2, 3, 3,
#        2, 3, 3, 1, 3, 2, 1, 2, 3, 3, 1, 3, 3, 3, 1, 1, 1, 2, 3, 3, 1, 1,
#        3, 2, 3, 3, 1, 1, 1, 3, 2, 1, 3, 1, 3, 2, 3, 3, 3, 3, 3, 3, 1, 3,
# ...

# %%
titanic.pclass.unique()
# Out:
# array([3, 1, 2])

# %%
titanic.pclass.nunique()  # 유니크 숫자가 3개다.
# Out:
# 3

# %%
titanic.nunique()
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
titanic.pclass.value_counts()  # 3등급 몇명 1등급 몇등... 많은거 부터
# Out:
# 3    491
# 1    216
# 2    184
# Name: pclass, dtype: int64

# %%
titanic.pclass.value_counts().sort_index()   ## 순서대로  // 체이닝 메소드
# Out:
# 1    216
# 2    184
# 3    491
# Name: pclass, dtype: int64

# %%
titanic.deck.value_counts()
# Out:
# C    59
# B    47
# D    33
# E    32
# A    15
# F    13
# G     4
# Name: deck, dtype: int64

# %% [markdown]
# ## 열 별 그룹화

# %%
titanic.groupby('sex')

# %%
titanic.groupby('sex').count()  ## 14개 칼럼에 대해서 다 알려줌. ('sex' 제외 )
# Out:
#         survived  pclass  age  sibsp  parch  fare  embarked  class  who  \
# sex
# female       314     314  261    314    314   314       312    314  314
# male         577     577  453    577    577   577       577    577  577
#
#         adult_male  deck  embark_town  alive  alone
# sex
# female         314    97          312    314    314
# male           577   106          577    577    577

# %%
titanic.groupby('who').count()
# Out:
#        survived  pclass  sex  age  sibsp  parch  fare  embarked  class  \
# who
# child        83      83   83   83     83     83    83        83     83
# man         537     537  537  413    537    537   537       537    537
# woman       271     271  271  218    271    271   271       269    271
#
#        adult_male  deck  embark_town  alive  alone
# who
# child          83    13           83     83     83
# man           537    99          537    537    537
# woman         271    91          269    271    271

# %%
titanic.groupby('alive').count()
# Out:
#        survived  pclass  sex  age  sibsp  parch  fare  embarked  class  who  \
# alive
# no          549     549  549  424    549    549   549       549    549  549
# yes         342     342  342  290    342    342   342       340    342  342
#
#        adult_male  deck  embark_town  alone
# alive
# no            549    67          549    549
# yes           342   136          340    342

# %%
titanic.groupby('embark_town').count()
# Out:
#              survived  pclass  sex  age  sibsp  parch  fare  embarked  class  \
# embark_town
# Cherbourg         168     168  168  130    168    168   168       168    168
# Queenstown         77      77   77   28     77     77    77        77     77
# Southampton       644     644  644  554    644    644   644       644    644
#
#              who  adult_male  deck  alive  alone
# embark_town
# Cherbourg    168         168    69    168    168
# Queenstown    77          77     4     77     77
# Southampton  644         644   128    644    644

# %%
titanic.groupby('pclass')

# %%
titanic.groupby('pclass')['fare']

# %%
titanic.groupby('pclass')['fare'].mean()
# Out:
# pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: fare, dtype: float64

# %% [markdown]
# ## 막대 그래프

# %%
sns.barplot(data= titanic, x='sex',y='survived');  ## 높이: 평균  (data < 문구 생략 가능)

# %%
sns.barplot(data= titanic, x='sex',y='survived',hue='sex');

# %%
sns.barplot(titanic, x='pclass',y='survived',hue='sex');

# %%
sns.barplot(titanic, x='pclass',y='fare',hue='sex');

# %%
sns.barplot(titanic, x='deck',y='fare',hue='class');

# %%
sns.barplot(titanic, x='deck',y='survived',hue='class');

# %% [markdown]
# ## 단원 4 데이터 프레임 세계로!

# %%
import pandas as pd

df= pd.DataFrame({'name':['김지훈', '이유진','박동현','김민지'],
                 'english':[90,80,60,70],
                 'math':[50,60,100,20]})

df
# Out:
#   name  english  math
# 0  김지훈       90    50
# 1  이유진       80    60
# 2  박동현       60   100
# 3  김민지       70    20

# %%
df.describe(include='all')
# Out:
#        name    english        math
# count     4   4.000000    4.000000
# unique    4        NaN         NaN
# top     김지훈        NaN         NaN
# freq      1        NaN         NaN
# mean    NaN  75.000000   57.500000
# std     NaN  12.909944   33.040379
# min     NaN  60.000000   20.000000
# 25%     NaN  67.500000   42.500000
# 50%     NaN  75.000000   55.000000
# 75%     NaN  82.500000   70.000000
# max     NaN  90.000000  100.000000

# %% [markdown]
# ## 특정 변수값 추출하기

# %%
df['math']
# Out:
# 0     50
# 1     60
# 2    100
# 3     20
# Name: math, dtype: int64

# %%
sum(df['math'])
# Out:
# 230

# %%
sum(df['english'])
# Out:
# 300

# %%
df['math'].sum()
# Out:
# 230

# %%
df['english'].sum()
# Out:
# 300

# %%
sum(df['math'])/len(df)
# Out:
# 57.5

# %%
sum(df['english'])/len(df)
# Out:
# 75.0

# %%
df['english'].mean()  ## = df.english.mean()
# Out:
# 75.0

# %%
df.sum()
# Out:
# name       김지훈이유진박동현김민지
# english             300
# math                230
# dtype: object

# %%
df.sum(axis=0)  ## 위에서 아래로 // axis= 1 왼쪽에서 오른쪽으로
# Out:
# name       김지훈이유진박동현김민지
# english             300
# math                230
# dtype: object

# %%
df.sum(axis=0,numeric_only=True)
# Out:
# english    300
# math       230
# dtype: int64

# %%
df.sum(axis=1,numeric_only=True)
# Out:
# 0    140
# 1    140
# 2    160
# 3     90
# dtype: int64

# %%
df.sum(numeric_only=True)
# Out:
# english    300
# math       230
# dtype: int64

# %%
df.sum(axis=1,numeric_only=True) ## 1 = columns /  0 = index
# Out:
# 0    140
# 1    140
# 2    160
# 3     90
# dtype: int64

# %%
df.sum(axis='columns',numeric_only=True)
# Out:
# 0    140
# 1    140
# 2    160
# 3     90
# dtype: int64

# %%
df.sum(axis='index',numeric_only=True)
# Out:
# english    300
# math       230
# dtype: int64

# %%
df.mean(axis=0,numeric_only=True)
# Out:
# english    75.0
# math       57.5
# dtype: float64

# %% [markdown]
# ## 외부 데이터 이용하기 - 축적된 시험 성적 데이터를 불러오자!

# %%
df_exam = pd.read_excel('excel_exam.xlsx')
df_exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
sum(df_exam['english']) / len(df_exam)
# Out:
# 84.9

# %%
df_exam['english'].mean()  ## = df_exam.english.mean()
# Out:
# 84.9

# %%
# 과학 성적 평균
df_exam.science.mean() ## = sum(df_exam['science']/20)  = sum(df_exam['science]/len(df_exam))
# Out:
# 59.45

# %% [markdown]
# #### 엑셀 파일의 첫 번쨰 행이 변수명이 아니라면?

# %%
df_exam_novar= pd.read_excel('excel_exam_novar.xlsx')
df_exam_novar
# Out:
#    1  1.1  50  98  50.1
# 0  2    1  60  97    60
# 1  3    2  25  80    65
# 2  4    2  50  89    98
# 3  5    3  20  98    15
# 4  6    3  50  98    45
# 5  7    4  46  98    65
# 6  8    4  48  87    12

# %%
df_exam_novar= pd.read_excel('excel_exam_novar.xlsx', header=None)
df_exam_novar
# Out:
#    0  1   2   3   4
# 0  1  1  50  98  50
# 1  2  1  60  97  60
# 2  3  2  25  80  65
# 3  4  2  50  89  98
# 4  5  3  20  98  15
# 5  6  3  50  98  45
# 6  7  4  46  98  65
# 7  8  4  48  87  12

# %% [markdown]
# #### 엑셀 파일에 시트가 여러 개 있다면?

# %%
# sheet2 시트의 데이터 불러오기

df_exam = pd.read_excel('excel_exam.xlsx', sheet_name='Sheet2')
df_exam.head()
# Out:
#    id  nclass  math  english  science
# 0   1       1   100      100       98
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65

# %%
# 세 번쨰 시트의 데이터 불러오기

df_exam = pd.read_excel('excel_exam.xlsx', sheet_name=2)
df_exam.head()
# Out:
#    id  nclass  math  english  science
# 0   1       1   100      100       98
# 1   2       1    90       90       90
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65

# %%
df_exam.tail()
# Out:
#     id  nclass  math  english  science
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
df_csv_exam = pd.read_csv('exam.csv')
df_csv_exam.head()
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65

# %%
df_csv_exam.to_csv("output_newdata.csv")

# %%
df_csv_exam.to_csv("output_newdata_noindex.csv")

# %% [markdown]
# ## 혼자서 해보기

# %%
# Q1.

mydf=pd.DataFrame({'제품':['사과','딸기','수박'],
                 '가격':['1800','1500','3000'],
                 '판매량':['24','38','13']})

mydf
# Out:
#    제품    가격 판매량
# 0  사과  1800  24
# 1  딸기  1500  38
# 2  수박  3000  13

# %%
# Q2.

mydf.sum(axis=0,numeric_only=True)
# Out:
# Series([], dtype: float64)

# %%
mydf.mean(axis=0,numeric_only=True)
# Out:
# Series([], dtype: float64)

# %%
mydf.sum(axis=1,numeric_only=True)
# Out:
# 0    0.0
# 1    0.0
# 2    0.0
# dtype: float64

# %%
mydf.mean(axis=1,numeric_only=True)
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# dtype: float64

# %% [markdown]
# ## 정리하기

# %%
# 1. 데이터 프레임 만들기

df= pd.DataFrame({'name':['김지훈', '이유진','박동현','김민지'],
                 'english':[90,80,60,70],
                 'math':[50,60,100,20]})

# %%
# 2. 외부 데이터 이용하기

df_exam = pd.read_excel('excel_exam.xlsx')

# %%
# 3. csv 파일 불러오기
df_csv_exam = pd.read_csv('exam.csv')

# %%
# 4. csv 파일로 저장하기


df_midterm= pd.DataFrame({'english':[90,80,60,70]
                          'math':[50,60,100,20],
                          'nclass':[1,1,2,2]})

df_midterm.to_csv('output_newdata2.csv')
df_midterm.to_csv('output_newdata3.csv', index=False)
# Out:
#   File "<ipython-input-154-418f4380b9a3>", line 4
#     df_midterm= pd.DataFrame({'english':[90,80,60,70]
#                                         ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
